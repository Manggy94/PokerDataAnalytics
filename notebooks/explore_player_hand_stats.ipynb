# %%
from dotenv import load_dotenv
load_dotenv()
import numpy as np

# %%
from src.data.loader import DataLoader
data_loader = DataLoader()

# %%
player_hand_stats = data_loader.load_player_hand_stats()
player_hand_stats.shape
# Out:
# (2216200, 133)

# %%
player_hand_stats.head()
# Out:
#       id  player  general_stats  preflop_stats  flop_stats  turn_stats  \
# 0  68015       2          68097          68015       68015       68015
# 1  68016    4646          68098          68016       68016       68016
# 2  68013    4644          68095          68013       68013       68013
# 3  68012    4643          68094          68012       68012       68012
# 4  68014    4645          68096          68014       68014       68014
#
#    river_stats                             hand_id                 hand_date  \
# 0        68015  1016186032418193414-100-1528204618 2018-06-05 13:16:58+00:00
# 1        68016  1016186032418193414-100-1528204618 2018-06-05 13:16:58+00:00
# 2        68013  1016186032418193414-100-1528204618 2018-06-05 13:16:58+00:00
# 3        68012  1016186032418193414-100-1528204618 2018-06-05 13:16:58+00:00
# 4        68014  1016186032418193414-100-1528204618 2018-06-05 13:16:58+00:00
#
#    tournament  ...  all_in_street  face_covering_bet_street  \
# 0         504  ...            NaN                       NaN
# 1         504  ...            NaN                       NaN
# 2         504  ...            NaN                       NaN
# 3         504  ...            NaN                       NaN
# 4         504  ...            NaN                       NaN
#
#    face_all_in_street  facing_covering_bet_move  facing_all_in_move  \
# 0                 NaN                       NaN                 NaN
# 1                 NaN                       NaN                 NaN
# 2                 NaN                       NaN                 NaN
# 3                 NaN                       NaN                 NaN
# 4                 NaN                       NaN                 NaN
#
#    starting_stack_bb  amount_won_bb chips_difference_bb  \
# 0             20.510           7.44                2.60
# 1             50.276           0.00               -0.12
# 2             67.104           0.00               -0.12
# 3             96.460           0.00               -1.12
# 4             42.295           0.00               -0.12
#
#   amount_expected_won_bb total_bet_amount_bb
# 0                    0.0                4.72
# 1                    0.0                0.00
# 2                    0.0                0.00
# 3                    0.0                0.00
# 4                    0.0                0.00
#
# [5 rows x 133 columns]

# %%
player_hand_stats.describe()
# Out:
#                  id        player  general_stats  preflop_stats    flop_stats  \
# count  2.216200e+06  2.216200e+06   2.216200e+06   2.216200e+06  2.216200e+06
# mean   1.134901e+06  2.918550e+04   1.112321e+06   1.115223e+06  1.116267e+06
# std    6.614051e+05  2.171751e+04   6.431442e+05   6.454846e+05  6.463190e+05
# min    1.000000e+00  1.000000e+00   1.000000e+00   1.000000e+00  1.000000e+00
# 25%    5.540828e+05  9.113000e+03   5.540758e+05   5.540758e+05  5.540758e+05
# 50%    1.136640e+06  2.848400e+04   1.112672e+06   1.115784e+06  1.116966e+06
# 75%    1.713941e+06  4.748000e+04   1.670270e+06   1.675878e+06  1.677879e+06
# max    2.267991e+06  7.053300e+04   2.224320e+06   2.229928e+06  2.231929e+06
#
#          turn_stats   river_stats    tournament   max_players   cnt_players  \
# count  2.216200e+06  2.216200e+06  2.216200e+06  2.216200e+06  2.216200e+06
# mean   1.118304e+06  1.120148e+06  3.552275e+03  6.414950e+00  6.002720e+00
# std    6.479719e+05  6.494638e+05  1.869292e+03  9.716587e-01  1.064072e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00  2.000000e+00
# 25%    5.540748e+05  5.540748e+05  1.758000e+03  6.000000e+00  6.000000e+00
# 50%    1.119088e+06  1.121016e+06  3.869000e+03  6.000000e+00  6.000000e+00
# 75%    1.681833e+06  1.685404e+06  5.223000e+03  6.000000e+00  6.000000e+00
# max    2.235883e+06  2.239454e+06  6.842000e+03  1.000000e+01  1.000000e+01
#
#        ...    amount_won  chips_difference  amount_expected_won  \
# count  ...  2.152323e+06      2.152323e+06            2152323.0
# mean   ...  1.049110e+04      2.155271e+02                  0.0
# std    ...  1.714081e+05      7.960936e+04                  0.0
# min    ...  0.000000e+00     -2.709410e+07                  0.0
# 25%    ...  0.000000e+00     -7.800000e+02                  0.0
# 50%    ...  0.000000e+00     -1.400000e+02                  0.0
# 75%    ...  0.000000e+00     -2.500000e+01                  0.0
# max    ...  7.939331e+07      2.825410e+07                  0.0
#
#        total_bet_amount  player_combo_hand_rank_difference  starting_stack_bb  \
# count      2.152323e+06                      590928.000000       2.152323e+06
# mean       8.903979e+03                           3.486516       5.368833e+01
# std        1.375818e+05                           2.664116       4.811348e+01
# min        0.000000e+00                           0.000000       8.000000e-04
# 25%        0.000000e+00                           1.000000       2.048565e+01
# 50%        0.000000e+00                           3.000000       3.898700e+01
# 75%        8.660000e+02                           5.000000       7.428650e+01
# max        5.099921e+07                          11.000000       1.002460e+03
#
#        amount_won_bb  chips_difference_bb  amount_expected_won_bb  \
# count   2.152323e+06         2.152323e+06               2152323.0
# mean    4.578052e+00         1.102655e-01                     0.0
# std     1.950883e+01         1.154155e+01                     0.0
# min     0.000000e+00        -6.014571e+02                     0.0
# 25%     0.000000e+00        -6.366667e-01                     0.0
# 50%     0.000000e+00        -1.250000e-01                     0.0
# 75%     0.000000e+00        -1.142857e-01                     0.0
# max     1.001860e+03         8.018600e+02                     0.0
#
#        total_bet_amount_bb
# count         2.152323e+06
# mean          4.094360e+00
# std           1.465398e+01
# min           0.000000e+00
# 25%           0.000000e+00
# 50%           0.000000e+00
# 75%           2.000000e+00
# max           1.001840e+03
#
# [8 rows x 33 columns]

# %%
player_hand_stats.select_dtypes(include=["object"]).describe()
# Out:
#                                    hand_id hero_combo_short_name  \
# count                              2216200               2214589
# unique                              383155                  1326
# top     2798446681136300034-113-1683546188                  8s2h
# freq                                    13                  2009
#
#        hero_combo_hand hero_combo_hand_is_suited hero_combo_hand_is_offsuit  \
# count          2214589                   2214589                    2214589
# unique             169                         2                          2
# top                52o                     False                       True
# freq             20746                   1692725                    1561444
#
#        hero_combo_hand_is_paired hero_combo_hand_is_connector  \
# count                    2214589                      2214589
# unique                         2                            2
# top                        False                        False
# freq                     2083308                      1865311
#
#        hero_combo_hand_is_one_gapper hero_combo_hand_is_two_gapper  \
# count                        2214589                       2214589
# unique                             2                             2
# top                            False                         False
# freq                         1893878                       1921638
#
#        hero_combo_hand_is_broadway  ... player_position_is_early  \
# count                      2214589  ...                  2152323
# unique                           2  ...                        2
# top                          False  ...                    False
# freq                       1897874  ...                  1857153
#
#        player_position_is_middle player_position_is_late  \
# count                    2152323                 2152323
# unique                         2                       2
# top                        False                   False
# freq                     1758535                 1434771
#
#        player_position_is_blind fold_street all_in_street  \
# count                   2152323     1641132        189081
# unique                        2           4             4
# top                       False          PF            PF
# freq                    1406510     1449250        132661
#
#        face_covering_bet_street face_all_in_street facing_covering_bet_move  \
# count                    258325                  0                   258325
# unique                        4                  0                        4
# top                          PF                NaN                        R
# freq                     195237                NaN                   119505
#
#        facing_all_in_move
# count                   0
# unique                  0
# top                   NaN
# freq                  NaN
#
# [4 rows x 99 columns]
