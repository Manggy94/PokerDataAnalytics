# %%
import numpy as np
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from src.data.loader import DataLoader
data_loader = DataLoader()

# %%
tournaments = data_loader.load_tournaments()
tournaments.shape
# Out:
# (6484, 33)

# %%
tournaments
# Out:
#         id tournament_id  total_players  final_position  \
# 3295     1     125561321           3950             646
# 3271     4     126839490             10               5
# 3272     2     125561322           3715             323
# 4373     5     126846691             10               2
# 3286     3     125561323           4105            1592
# ...    ...           ...            ...             ...
# 4322  6423     823574092           5889            1656
# 4329  6433     823766885           3132            2374
# 6424  6432     823577915            476              16
# 4325  6426     823575643             84              39
# 4319  6421     822999264           4713            3930
#
#                     start_date  amount_won  bounty_won  prize_pool  \
# 3295 2015-08-07 12:00:00+00:00        0.00        0.00      100.00
# 3271 2015-08-07 13:11:02+00:00        0.00        0.00        0.10
# 3272 2015-08-07 13:30:00+00:00        0.12        0.00      100.00
# ...

# %%
tournaments.dtypes
# Out:
# id                                                             int64
# tournament_id                                                 object
# total_players                                                  int64
# final_position                                                 int32
# start_date                                       datetime64[ns, UTC]
# amount_won                                                   float64
# bounty_won                                                   float64
# prize_pool                                                   float64
# nb_entries                                                     int64
# ref_tournament_name                                           object
# ref_tournament_starting_stack                                  int64
# ref_tournament_is_ko                                            bool
# ref_tournament_buy_in_prize_pool_contribution                float64
# ref_tournament_buy_in_bounty                                 float64
# ...

# %%
from src.graphs.tournaments import TournamentGraphs
tournament_graphs = TournamentGraphs(tournaments)
tournament_graphs.plot_profit_over_time()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 from src.graphs.tournaments import TournamentGraphs
# ----> 2 tournament_graphs = TournamentGraphs(tournaments)
#       3 tournament_graphs.plot_profit_over_time()
#
# File ~\projects\PokerDataAnalytics\src\graphs\tournaments.py:14, in TournamentGraphs.__init__(self, tournaments)
#      12 def __init__(self, tournaments: pd.DataFrame):
#      13     self.tournaments = tournaments
# ---> 14     self.tournaments_grouped = self.tournaments.groupby(["buy_in_total", "tournament_type", "speed", "total_players_range"])
#      15     self.tournaments_resume = self.tournaments_grouped\
#      16         .agg(
#      17             nb_played=("tournament_id", "count"),
#    (...)
#      24             ITM=("ITM", "mean")
#      25         ).reset_index()
#
# ...

# %%
tournament_graphs.plot_profit_distribution()

# %%
tournaments_resume = tournament_graphs.tournaments_resume
tournaments_resume = tournaments_resume[tournaments_resume["nb_played"] > 10]
tournaments_resume = tournaments_resume[tournaments_resume["buy_in_total"] > 0].sort_values("mean_roi", ascending=False)

# %%
tournaments_resume
# Out:
#       buy_in_total tournament_type    speed total_players_range  nb_played  \
# 335           0.25         CLASSIC  REGULAR           101 - 200         12
# 3786         10.00              KO  REGULAR           201 - 500         36
# 2989          5.00         CLASSIC    TURBO            51 - 100         24
# 1161          1.00              KO    TURBO           201 - 500         74
# 2151          2.00              KO    TURBO           201 - 500        166
# ...            ...             ...      ...                 ...        ...
# 528           0.25          QUALIF    TURBO             21 - 50         31
# 797           0.50         HITNRUN    TURBO             11 - 20         16
# 799           0.50         HITNRUN    TURBO            51 - 100         67
# 1188          1.00          QUALIF    TURBO             21 - 50         16
# 4071         15.00          FLIGHT    TURBO           201 - 500         11
#
#       total_profit  mean_profit  mean_roi  mean_finish_percentage  \
# ...

# %%
tournament_graphs.plot_roi_vs_finish_position()
# Out:
# <div>                            <div id="c7e6e308-b0ff-4c95-92fb-c68604091b4d" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7e6e308-b0ff-4c95-92fb-c68604091b4d")) {                    Plotly.newPlot(                        "c7e6e308-b0ff-4c95-92fb-c68604091b4d",                        [{"marker":{"color":"blue","opacity":0.7},"mode":"markers","name":"ROI vs Finish Position","x":[16.354430379746834,8.694481830417228,38.78197320341047,4.669073405535499,83.2251862533045,67.01123595505618,99.03999999999999,2.728912945421741,64.16913946587538,81.15621156211562,97.1764705882353,18.442321822189566,87.65666540068364,69.10025706940874,71.93236714975846,7.04647676161919,30.259999999999998,11.508951406649617,30.31301482701812,9.71651157758061,55.0270513
# ...

# %%
tournament_graphs.plot_mean_roi_by_categories()
# Out:
# <div>                            <div id="52f84dea-0d8f-4e62-bb01-3a6ff5fb759a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52f84dea-0d8f-4e62-bb01-3a6ff5fb759a")) {                    Plotly.newPlot(                        "52f84dea-0d8f-4e62-bb01-3a6ff5fb759a",                        [{"hovertemplate":"total_players_range=101 - 200\u003cbr\u003espeed=REGULAR\u003cbr\u003eBuy-in total=%{x}\u003cbr\u003eTournament type=%{y}\u003cbr\u003eMean ROI=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"101 - 200, REGULAR","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"101 - 200, REGULAR","scene":"scene","showlegend":true,"x":[0.25,2.0,5.0],"y":["CLASSIC","CLASSIC","CLASSIC"],"z":[1.6850000000000003,-0.1
# ...

# %%
tournament_graphs.plot_mean_profit_by_categories()
# Out:
# <div>                            <div id="30081ccb-7b70-421c-a04a-0edac93f372d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30081ccb-7b70-421c-a04a-0edac93f372d")) {                    Plotly.newPlot(                        "30081ccb-7b70-421c-a04a-0edac93f372d",                        [{"hovertemplate":"total_players_range=101 - 200\u003cbr\u003espeed=REGULAR\u003cbr\u003eBuy-in total=%{x}\u003cbr\u003eTournament type=%{y}\u003cbr\u003eMean Profit=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"101 - 200, REGULAR","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"101 - 200, REGULAR","scene":"scene","showlegend":true,"x":[0.25,2.0,5.0],"y":["CLASSIC","CLASSIC","CLASSIC"],"z":[0.39916666666666667,
# ...

# %%
tournament_graphs.plot_ITM_by_categories()
# Out:
# <div>                            <div id="77f2e7d1-35ab-4bb3-88f9-dfca584309cb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77f2e7d1-35ab-4bb3-88f9-dfca584309cb")) {                    Plotly.newPlot(                        "77f2e7d1-35ab-4bb3-88f9-dfca584309cb",                        [{"hovertemplate":"total_players_range=101 - 200\u003cbr\u003espeed=REGULAR\u003cbr\u003eBuy-in total=%{x}\u003cbr\u003eTournament type=%{y}\u003cbr\u003eITM=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"101 - 200, REGULAR","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"101 - 200, REGULAR","scene":"scene","showlegend":true,"x":[0.25,2.0,5.0],"y":["CLASSIC","CLASSIC","CLASSIC"],"z":[0.16666666666666666,0.09375,
# ...
