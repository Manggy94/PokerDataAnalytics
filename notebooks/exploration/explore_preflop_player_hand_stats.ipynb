# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src.data.loader import DataLoader
data_loader = DataLoader()

# %%
preflop_player_hand_stats = data_loader.load_preflop_player_hand_stats()
preflop_player_hand_stats.head()
# Out:
#         id  player  hand_history  flag_vpip  flag_open_opportunity  flag_open  \
# 0       49       2          2474       True                  False       True
# 1       50     163          2474      False                  False      False
# 2        5     166          2466      False                  False      False
# 3        6     167          2466       True                  False       True
# 4  1589400   47579        279464       True                  False      False
#
#    flag_first_raise  flag_fold  flag_limp  flag_cold_called  ...  \
# 0             False      False       True             False  ...
# 1             False       True      False             False  ...
# 2             False       True      False             False  ...
# 3             False      False      False              True  ...
# 4             False      False      False             False  ...
#
#    ratio_to_call_facing_4bet  ratio_first_raise_made  ratio_second_raise_made  \
# ...

# %%
preflop_player_hand_stats.shape
# Out:
# (2229903, 53)

# %%
preflop_player_hand_stats.describe()
# Out:
#                  id        player  hand_history  count_player_raises  \
# count  2.229903e+06  2.229903e+06  2.229903e+06         2.229903e+06
# mean   1.114974e+06  2.920143e+04  1.931350e+05         1.653045e-01
# std    6.437218e+05  2.170506e+04  1.144758e+05         3.809722e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00         0.000000e+00
# 25%    5.575015e+05  9.134000e+03  9.049600e+04         0.000000e+00
# 50%    1.114977e+06  2.854800e+04  1.943400e+05         0.000000e+00
# 75%    1.672452e+06  4.748000e+04  2.929580e+05         0.000000e+00
# max    2.229928e+06  7.053300e+04  3.909550e+05         3.000000e+00
#
#        count_player_calls  count_faced_limps  amount_effective_stack  \
# count        2.229903e+06       2.229903e+06            2.229903e+06
# mean         1.731470e-01       3.842320e-03            6.717062e+04
# std          4.176100e-01       7.863090e-02            3.272717e+05
# ...

# %%
preflop_player_hand_stats.select_dtypes(include="object").describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 preflop_player_hand_stats.select_dtypes(include="object").describe()
#
# File ~\projects\Environnements\3.10\PokerBrainEnv\lib\site-packages\pandas\core\generic.py:10232, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9983 @final
#    9984 def describe(
#    9985     self: NDFrameT,
#    (...)
#    9989     datetime_is_numeric=False,
#    9990 ) -> NDFrameT:
#    9991     """
#    9992     Generate descriptive statistics.
#    9993
#    (...)
#   10230     max            NaN      3.0
#   10231     """
# > 10232     return describe_ndframe(
#   10233         obj=self,
#   10234         include=include,
#   10235         exclude=exclude,
#   10236         datetime_is_numeric=datetime_is_numeric,
#   10237         percentiles=percentiles,
#   10238     )
#
# ...
