# %%
from dotenv import load_dotenv
load_dotenv()
from src.data.loader import DataLoader

# %%
data_loader = DataLoader()

# %%
hand_histories = data_loader.load_hand_histories()
hand_histories.head()
# Out:
#       id                 hand_date  max_players  cnt_players  button_seat  \
# 0  39804 2015-08-07 12:00:28+00:00            6            6            2
# 1  39805 2015-08-07 12:01:39+00:00            6            6            3
# 2  39802 2015-08-07 12:03:00+00:00            6            6            3
# 3  39803 2015-08-07 12:03:34+00:00            6            5            4
# 4  39806 2015-08-07 12:04:16+00:00            6            6            5
#
#   tournament_id  ref_tournament_buy_in_total ref_tournament_speed  \
# 0     125561321                          0.0                TURBO
# 1     125561321                          0.0                TURBO
# 2     125561321                          0.0                TURBO
# 3     125561321                          0.0                TURBO
# 4     125561321                          0.0                TURBO
#
#   ref_tournament_type total_players_range  ...  turn_card_short_name  \
# 0             CLASSIC         2001 - 5000  ...                    2c
# 1             CLASSIC         2001 - 5000  ...                    Js
# 2             CLASSIC         2001 - 5000  ...                    2c
# 3             CLASSIC         2001 - 5000  ...                    Ts
# 4             CLASSIC         2001 - 5000  ...                    2s
#
#    turn_card_is_broadway  turn_card_is_face  turn_card_rank turn_card_suit  \
# 0                  False              False               2              c
# 1                   True               True               J              s
# 2                  False              False               2              c
# 3                   True              False               T              s
# 4                  False              False               2              s
#
#   river_card_short_name  river_card_is_broadway  river_card_is_face  \
# 0                    Jh                    True                True
# 1                    7h                   False               False
# 2                    5h                   False               False
# 3                    6s                   False               False
# 4                    Qc                    True                True
#
#    river_card_rank  river_card_suit
# 0                J                h
# 1                7                h
# 2                5                h
# 3                6                s
# 4                Q                c
#
# [5 rows x 76 columns]

# %%
hand_histories.level_value
# Out:
# 0          1
# 1          1
# 2          1
# 3          2
# 4          2
#           ..
# 383150     1
# 383151    10
# 383152    10
# 383153    10
# 383154    10
# Name: level_value, Length: 383155, dtype: Int16

# %%
hand_histories.level_value.describe()
# Out:
# count    383155.000000
# mean         10.429100
# std           7.865857
# min           0.000000
# 25%           4.000000
# 50%           9.000000
# 75%          15.000000
# max         166.000000
# Name: level_value, dtype: float64

# %%
hand_histories.shape
# Out:
# (383155, 76)

# %%
memory_used = hand_histories.memory_usage(deep=True).sum()

# %%
print(f"Memory used: {memory_used / 1024 ** 2:.2f} MB, {memory_used / 1024 ** 3:.2f} GB")
# Out:
# Memory used: 44.32 MB, 0.04 GB

# %%
hand_histories.describe()
# Out:
#                   id    max_players    cnt_players    button_seat  \
# count  383155.000000  383155.000000  383155.000000  383155.000000
# mean   195606.461756       6.265827       5.769441       3.630946
# std    113863.597623       1.026848       1.166572       1.880291
# min         1.000000       2.000000       2.000000       1.000000
# 25%     95807.500000       6.000000       5.000000       2.000000
# 50%    195863.000000       6.000000       6.000000       4.000000
# 75%    295166.500000       6.000000       6.000000       5.000000
# max    390955.000000      10.000000      10.000000      10.000000
#
#        ref_tournament_buy_in_total    level_value  level_sb  level_bb  \
# count                     383155.0  383155.000000  383155.0  383155.0
# mean                           NaN      10.429100       NaN       NaN
# std                            0.0       7.865857       NaN       NaN
# min                            0.0       0.000000      10.0      20.0
# 25%                            1.0       4.000000     150.0     300.0
# 50%                            2.0       9.000000     350.0     700.0
# 75%                            5.0      15.000000     800.0    1600.0
# max                           50.0     166.000000       inf       inf
#
#        level_ante  hero_combo_hand_rank_difference  flop_min_distance  \
# count    383155.0                    382845.000000      241021.000000
# mean          NaN                         3.954546           1.562959
# std           NaN                         2.693459           1.157367
# min           0.0                         0.000000           0.000000
# 25%          35.0                         2.000000           1.000000
# 50%          80.0                         4.000000           1.000000
# 75%         200.0                         6.000000           2.000000
# max           inf                        11.000000           5.000000
#
#        flop_max_distance
# count      241021.000000
# mean            5.964787
# std             2.503885
# min             0.000000
# 25%             4.000000
# 50%             6.000000
# 75%             8.000000
# max            11.000000

# %%
hand_histories.dtypes
# Out:
# id                                      int64
# hand_date                 datetime64[ns, UTC]
# max_players                              Int8
# cnt_players                              Int8
# button_seat                              Int8
#                                  ...
# river_card_short_name                category
# river_card_is_broadway                   bool
# river_card_is_face                       bool
# river_card_rank                      category
# river_card_suit                      category
# Length: 76, dtype: object

# %%
hand_histories.select_dtypes(include="boolean").describe()
# Out:
#        hero_combo_hand_is_suited hero_combo_hand_is_offsuit  \
# count                     383155                     383155
# unique                         2                          2
# top                        False                       True
# freq                      292618                     270168
#
#        hero_combo_hand_is_paired hero_combo_hand_is_connector  \
# count                     383155                       383155
# unique                         2                            2
# top                        False                        False
# freq                      360085                       322553
#
#        hero_combo_hand_is_one_gapper hero_combo_hand_is_two_gapper  \
# count                         383155                        383155
# unique                             2                             2
# top                            False                         False
# freq                          327411                        332258
#
#        hero_combo_hand_is_broadway hero_combo_hand_is_face  \
# count                       383155                  383155
# unique                           2                       2
# top                          False                   False
# freq                        328190                  363617
#
#        hero_combo_hand_is_suited_connector hero_combo_first_card_is_broadway  \
# count                               383155                            383155
# unique                                   2                                 2
# top                                  False                              True
# freq                                367630                            239917
#
#         ... flop_first_card_is_broadway flop_first_card_is_face  \
# count   ...                      383155                  383155
# unique  ...                           2                       2
# top     ...                        True                    True
# freq    ...                      327548                  252514
#
#        flop_second_card_is_broadway flop_second_card_is_face  \
# count                        383155                   383155
# unique                            2                        2
# top                            True                    False
# freq                         218954                   192250
#
#        flop_third_card_is_broadway flop_third_card_is_face  \
# count                       383155                  383155
# unique                           2                       2
# top                          False                   False
# freq                        229110                  235209
#
#        turn_card_is_broadway turn_card_is_face river_card_is_broadway  \
# count                 383155            383155                 383155
# unique                     2                 2                      2
# top                     True              True                   True
# freq                  268351            240899                 289294
#
#        river_card_is_face
# count              383155
# unique                  2
# top                  True
# freq               266822
#
# [4 rows x 32 columns]
