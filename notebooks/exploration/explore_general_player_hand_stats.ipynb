# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src.data.loader import DataLoader
loader = DataLoader()

# %%
general_player_hand_stats = loader.load_general_player_hand_stats()

# %%
general_player_hand_stats.head()
# Out:
#         id  player  hand_history  flag_went_to_showdown  flag_is_hero  \
# 0   681519       2        117212                   True          True
# 1  1279556   53014        227139                  False         False
# 2  1279559   16408        227139                  False         False
# 3  1279563       2        227139                  False          True
# 4  1279588   53015        227139                  False         False
#
#    flag_won_hand  starting_stack    bounty  amount_won  chips_difference  ...  \
# 0           True             inf  0.000000         inf               inf  ...
# 1          False         23472.0  9.000000         0.0           -1800.0  ...
# 2          False         30784.0  4.500000         0.0            -200.0  ...
# 3          False         63872.0  7.871094         0.0            -200.0  ...
# 4           True             inf  6.750000      6600.0            3200.0  ...
#
#    player_position_is_early  player_position_is_middle  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                       True
# 3                     False                      False
# 4                     False                      False
#
#    player_position_is_late player_position_is_blind fold_street  \
# 0                     True                    False         NaN
# 1                    False                     True          PF
# 2                    False                    False          PF
# 3                     True                    False          PF
# 4                     True                    False         NaN
#
#    all_in_street  face_covering_bet_street  face_all_in_street  \
# 0              T                         T                 NaN
# 1            NaN                       NaN                 NaN
# 2            NaN                       NaN                 NaN
# 3            NaN                       NaN                 NaN
# 4            NaN                       NaN                 NaN
#
#    facing_covering_bet_move  facing_all_in_move
# 0                         C                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
#
# [5 rows x 49 columns]

# %%
general_player_hand_stats.shape
# Out:
# (2152323, 49)

# %%
general_player_hand_stats.describe()
# Out:
#                  id        player  hand_history  starting_stack      bounty  \
# count  2.152323e+06  2.152323e+06  2.152323e+06       2152323.0  2152323.00
# mean   1.113693e+06  2.908358e+04  1.933027e+05             NaN         NaN
# std    6.514430e+05  2.179131e+04  1.162605e+05             NaN         NaN
# min    1.000000e+00  1.000000e+00  1.000000e+00             2.0        0.00
# 25%    5.386735e+05  8.960000e+03  8.730200e+04         16656.0        0.00
# 50%    1.116541e+06  2.811900e+04  1.948450e+05         25536.0        0.00
# 75%    1.686240e+06  4.747800e+04  2.961960e+05         58752.0        2.25
# max    2.224320e+06  7.053300e+04  3.909550e+05             inf      275.75
#
#        amount_won  chips_difference  amount_expected_won  total_bet_amount  \
# count   2152323.0         2152323.0            2152323.0         2152323.0
# mean          NaN               NaN                  0.0               NaN
# std           NaN               NaN                  0.0               NaN
# min           0.0              -inf                  0.0               0.0
# 25%           0.0            -780.0                  0.0               0.0
# 50%           0.0            -140.0                  0.0               0.0
# 75%           0.0             -25.0                  0.0             866.0
# max           inf               inf                  0.0               inf
#
#                seat  player_combo_hand_rank_difference
# count  2.152323e+06                      590928.000000
# mean   3.697414e+00                           3.486516
# std    1.917049e+00                           2.664116
# min    1.000000e+00                           0.000000
# 25%    2.000000e+00                           1.000000
# 50%    4.000000e+00                           3.000000
# 75%    5.000000e+00                           5.000000
# max    1.000000e+01                          11.000000

# %%
general_player_hand_stats.dtypes
# Out:
# id                                          int64
# player                                      int64
# hand_history                                int64
# flag_went_to_showdown                        bool
# flag_is_hero                                 bool
# flag_won_hand                                bool
# starting_stack                            float16
# bounty                                    float16
# amount_won                                float16
# chips_difference                          float16
# amount_expected_won                       float16
# total_bet_amount                          float16
# seat                                         Int8
# player_combo_short_name                  category
# player_combo_hand                        category
# player_combo_hand_is_suited                  bool
# player_combo_hand_is_offsuit                 bool
# player_combo_hand_is_paired                  bool
# player_combo_hand_is_connector               bool
# player_combo_hand_is_one_gapper              bool
# player_combo_hand_is_two_gapper              bool
# player_combo_hand_is_broadway                bool
# player_combo_hand_is_face                    bool
# player_combo_hand_is_suited_connector        bool
# player_combo_hand_rank_difference            Int8
# player_combo_hand_first_rank             category
# player_combo_hand_second_rank            category
# player_combo_hand_shape                  category
# player_combo_first_card_short_name       category
# player_combo_first_card_is_broadway          bool
# player_combo_first_card_is_face              bool
# player_combo_first_card_rank             category
# player_combo_first_card_suit             category
# player_combo_second_card_short_name      category
# player_combo_second_card_is_broadway         bool
# player_combo_second_card_is_face             bool
# player_combo_second_card_rank            category
# player_combo_second_card_suit            category
# player_position_name                     category
# player_position_is_early                     bool
# player_position_is_middle                    bool
# player_position_is_late                      bool
# player_position_is_blind                     bool
# fold_street                              category
# all_in_street                            category
# face_covering_bet_street                 category
# face_all_in_street                       category
# facing_covering_bet_move                 category
# facing_all_in_move                       category
# dtype: object
